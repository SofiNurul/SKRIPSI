# %% [markdown]
# <a href="https://colab.research.google.com/github/SofiNurul/SKRIPSI/blob/main/Prediksi_Sentiment_Analisis_Produk_Penghilang_Bekas_Luka_di_Shopee_Dengan_Algoritma_Naive_Bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMPORT LIBRARY DAN DATASET**
#
# ---

# %%
import pandas as pd
import re
import string
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from nltk.corpus import stopwords as nltk_stopwords
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix, precision_recall_fscore_support
from wordcloud import WordCloud
import joblib

# %% [markdown]
# Mengunduh resource nltk yang diperlukan

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# Muat dataset

# %%
df = pd.read_csv('dataulasan_produk.csv', encoding='MacRoman')
df.head(10)
# Out:
#    no                username        date  \
# 0   1                 z*****e  10/10/2024
# 1   2               dindardew  03/09/2024
# 2   3              dikamungil  03/09/2024
# 3   4             cakranouval  11/08/2024
# 4   5          ilhamansyari22  18/06/2024
# 5   6  inggihsatrianisatriani  18/06/2024
# 6   7                 m*****4  06/06/2024
# 7   8                  nonaa2  02/06/2024
# 8   9              linarifqun  12/05/2024
# 9  10                 v*****8  11/05/2024
#
#                                              content  \
# 0  Pertama kali coba karena baca ulasan di Quora ...
# 1  Penasaran bgt dari dulu udah laser jg bekas lu...
# 2  Udah ku pke beberapa kali sih, semoga bermanfa...
# 3                             kecewa, kemasan penyok
# 4                       Barang sesuai pesanan ‚ò∫Ô∏è
# 5  Baru pertama kali coba mudah mudahan bisa puda...
# 6  Baru mau nyoba, semoga manjur menghilangkan be...
# 7  Cottonbud gak dikasih, pelit banget, gimana pa...
# 8  Alhamdulillah Paketku sudah sampai pesanannya ...
# 9  Dikasih thr sama kakaknya, MasyaAllah berkah s...
#
#                       texture                             effectiveness  \
# 0                   cream gel  baru pertama x coba Guys mudah2an manjur
# 1  lembut dan dingin ke kulit             belum tau baru d pakai sehari
# 2                         gel                                      baik
# 3                  gel lembut                                   efektif
# 4                  gel lembut                                   efektif
# 5                        baik                        blom tau baru coba
# 6                         gel                                     bagus
# 7                         gel                                     bagus
# 8                         gel                                     bagus
# 9                  gel kental                semoga bekerja dengan baik
#
#   absorption capacity  score sentiment
# 0                 pas      4   positif
# 1               cepet      5    netral
# 2               cepat      5   positif
# 3               cepat      3   negatif
# 4               cepat      5    netral
# 5               bagus      5   positif
# 6               bagus      5   positif
# 7                baik      3   negatif
# 8               bagus      3   positif
# 9           belum tau      5   positif

# %% [markdown]
# # **DATA SELECTION**
#
# ---

# %% [markdown]
# Melakukan data selection

# %%
# Memilih kolom yang relevan
df_selected = df[['username', 'content', 'sentiment']]
# Menghapus baris yang memiliki nilai kosong pada kolom 'content'
df_selected.dropna(subset=['content'], inplace=True)
# Menampilkan 10 baris pertama dari data yang telah diseleksi
df_selected.head(10)
# Out:
# <ipython-input-4-140f985cd337>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected.dropna(subset=['content'], inplace=True)
#                  username                                            content  \
# 0                 z*****e  Pertama kali coba karena baca ulasan di Quora ...
# 1               dindardew  Penasaran bgt dari dulu udah laser jg bekas lu...
# 2              dikamungil  Udah ku pke beberapa kali sih, semoga bermanfa...
# 3             cakranouval                             kecewa, kemasan penyok
# 4          ilhamansyari22                       Barang sesuai pesanan ‚ò∫Ô∏è
# 5  inggihsatrianisatriani  Baru pertama kali coba mudah mudahan bisa puda...
# 6                 m*****4  Baru mau nyoba, semoga manjur menghilangkan be...
# 7                  nonaa2  Cottonbud gak dikasih, pelit banget, gimana pa...
# 8              linarifqun  Alhamdulillah Paketku sudah sampai pesanannya ...
# 9                 v*****8  Dikasih thr sama kakaknya, MasyaAllah berkah s...
#
#   sentiment
# 0   positif
# 1    netral
# 2   positif
# 3   negatif
# 4    netral
# 5   positif
# 6   positif
# 7   negatif
# 8   positif
# 9   positif

# %% [markdown]
# # **DATA PREPROCESSING**
#
# ---

# %% [markdown]
# Daftar stopwords dari NLTK dan tambahan khusus Bahasa Indonesia

# %%
stopwords_tambahan = list([
    'gk', 'yg', 'nya', 'dan', 'dll', 'saja', 'juga', 'untuk', 'dengan', 'atau',
    'tapi', 'karena', 'seperti', 'yang', 'saya', 'ga', 'malah', 'tidak', 'lagi',
    'ini', 'di', 'kok', 'aja', 'gak', 'jadi', 'ya', 'dah', 'bisa', 'ada', 'bgt',
    'banget', 'kak', 'ituu', 'grgr', 'jd', 'pengen', 'dgn', 'udah', 'klo', 'tp',
    'pa', 'udh', 'karin', 'bgtt', 'ig', 'po', 'tau', 'utk', 'karna', 'brangnya',
    'ngk', 'kyk', 'sy', 'tp', 'uda', 'nga', 'dngn', 'kalo', 'gamau', 'becak', 'kya',
    'sma', 'jdi', 'ad', 'lg', 'pa', 'huhu', 'dpt', 'gel', 'b', 'jg', 'rb', 'hehe',
    'pdhl', 'dr', 'ku', 'sih', 'ka', 'kyk', 'sy', 'bli', 'skali', 'dikrim', 'berharap',
    'kirim', 'jdi', 'pkai', 'penjual', 'brangnya', 'becak', 'tpi', 'blum', 'bgin'
])

# %% [markdown]
# Inisialisasi Stemmer dari Sastrawi

# %%
# !pip install Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()
# Out:
# Requirement already satisfied: Sastrawi in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %% [markdown]
# Pembersihan teks

# %%
def clean_text(teks):
    if not isinstance(teks, str):
        return ""
    teks = teks.lower()
    teks = re.sub(r'http\S+|www\S+|https\S+', '', teks)  # Menghapus URL
    teks = re.sub(r'[^\x00-\x7F]+', ' ', teks)  # Menghilangkan karakter non-ASCII
    teks = teks.translate(str.maketrans('', '', string.punctuation))  # Menghapus tanda baca
    teks = re.sub(r'\d+', '', teks)  # Menghapus angka
    return teks

# %% [markdown]
# Fungsi untuk tokenisasi

# %%
def tokenize(teks):
    return teks.split()

# %% [markdown]
# Fungsi untuk stemming

# %%
def apply_stemming(tokens):
    return [stemmer.stem(token) for token in tokens]

# %% [markdown]
# Terapkan pra-pemrosesan ke data

# %%
df_selected['cleaned_content'] = df_selected['content'].apply(clean_text)
# Out:
# <ipython-input-10-e0c27e1bd33e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['cleaned_content'] = df_selected['content'].apply(clean_text)

# %% [markdown]
# Menampilkan hasil tokenisasi dan stemming untuk 5 sampel teratas

# %%
print("\n=== Hasil Tokenisasi dan Stemming untuk 5 Sampel Teratas ===")
for i in range(5):  # Menampilkan 5 contoh pertama
    original_text = df_selected.iloc[i]['content']
    cleaned_text = df_selected.iloc[i]['cleaned_content']
    tokens = tokenize(cleaned_text)
    stemmed_tokens = apply_stemming(tokens)

    print(f"Contoh {i+1}:")
    print("Teks Asli:", original_text)
    print("Setelah Pembersihan:", cleaned_text)
    print("Setelah Tokenisasi:", tokens)
    print("Setelah Stemming:", stemmed_tokens)
    print("-" * 50)
# Out:
# === Hasil Tokenisasi dan Stemming untuk 5 Sampel Teratas ===
# Contoh 1:
# Teks Asli: Pertama kali coba karena baca ulasan di Quora katanya bagus, semoga ngefek bekas2 korengan pas hamil anak ke 2 memudar, hasilnya pemakaian 1 botol insyaallah akan aku update ya.. kalo emang bagus pasti repurchase (beli lagi) di toko ini, Sellernya ramah dan amanah.. suka kalo di chat gercep di balas gak pake lama, pengiriman ke Jakarta juga cepat.i
# Setelah Pembersihan: pertama kali coba karena baca ulasan di quora katanya bagus semoga ngefek bekas korengan pas hamil anak ke  memudar hasilnya pemakaian  botol insyaallah akan aku update ya kalo emang bagus pasti repurchase beli lagi di toko ini sellernya ramah dan amanah suka kalo di chat gercep di balas gak pake lama pengiriman ke jakarta juga cepati
# Setelah Tokenisasi: ['pertama', 'kali', 'coba', 'karena', 'baca', 'ulasan', 'di', 'quora', 'katanya', 'bagus', 'semoga', 'ngefek', 'bekas', 'korengan', 'pas', 'hamil', 'anak', 'ke', 'memudar', 'hasilnya', 'pemakaian', 'botol', 'insyaallah', 'akan', 'aku', 'update', 'ya', 'kalo', 'emang', 'bagus', 'pasti', 'repurchase', 'beli', 'lagi', 'di', 'toko', 'ini', 'sellernya', 'ramah', 'dan', 'amanah', 'suka', 'kalo', 'di', 'chat', 'gercep', 'di', 'balas', 'gak', 'pake', 'lama', 'pengiriman', 'ke', 'jakarta', 'juga', 'cepati']
# Setelah Stemming: ['pertama', 'kali', 'coba', 'karena', 'baca', 'ulas', 'di', 'quora', 'kata', 'bagus', 'moga', 'ngefek', 'bekas', 'koreng', 'pas', 'hamil', 'anak', 'ke', 'pudar', 'hasil', 'pakai', 'botol', 'insyaallah', 'akan', 'aku', 'update', 'ya', 'kalo', 'emang', 'bagus', 'pasti', 'repurchase', 'beli', 'lagi', 'di', 'toko', 'ini', 'sellernya', 'ramah', 'dan', 'amanah', 'suka', 'kalo', 'di', 'chat', 'gercep', 'di', 'balas', 'gak', 'pake', 'lama', 'kirim', 'ke', 'jakarta', 'juga', 'cepat']
# --------------------------------------------------
# Contoh 2:
# Teks Asli: Penasaran bgt dari dulu udah laser jg bekas luka gak ilang Nemu produk ini jadi coba aja dulu siapa tau cocok order 2 langsung kk
# Setelah Pembersihan: penasaran bgt dari dulu udah laser jg bekas luka gak ilang nemu produk ini jadi coba aja dulu siapa tau cocok order  langsung kk
# Setelah Tokenisasi: ['penasaran', 'bgt', 'dari', 'dulu', 'udah', 'laser', 'jg', 'bekas', 'luka', 'gak', 'ilang', 'nemu', 'produk', 'ini', 'jadi', 'coba', 'aja', 'dulu', 'siapa', 'tau', 'cocok', 'order', 'langsung', 'kk']
# Setelah Stemming: ['penasaran', 'bgt', 'dari', 'dulu', 'udah', 'laser', 'jg', 'bekas', 'luka', 'gak', 'ilang', 'nemu', 'produk', 'ini', 'jadi', 'coba', 'aja', 'dulu', 'siapa', 'tau', 'cocok', 'order', 'langsung', 'kk']
# --------------------------------------------------
# Contoh 3:
# Teks Asli: Udah ku pke beberapa kali sih, semoga bermanfaat. Makasih ya seller. Harganya mahal tp semoga ampuuuuh yaaaa
# Setelah Pembersihan: udah ku pke beberapa kali sih semoga bermanfaat makasih ya seller harganya mahal tp semoga ampuuuuh yaaaa
# Setelah Tokenisasi: ['udah', 'ku', 'pke', 'beberapa', 'kali', 'sih', 'semoga', 'bermanfaat', 'makasih', 'ya', 'seller', 'harganya', 'mahal', 'tp', 'semoga', 'ampuuuuh', 'yaaaa']
# Setelah Stemming: ['udah', 'ku', 'pke', 'beberapa', 'kali', 'sih', 'moga', 'manfaat', 'makasih', 'ya', 'seller', 'harga', 'mahal', 'tp', 'moga', 'ampuuuuh', 'yaaaa']
# --------------------------------------------------
# Contoh 4:
# Teks Asli: kecewa, kemasan penyok
# Setelah Pembersihan: kecewa kemasan penyok
# Setelah Tokenisasi: ['kecewa', 'kemasan', 'penyok']
# Setelah Stemming: ['kecewa', 'kemas', 'penyok']
# --------------------------------------------------
# Contoh 5:
# Teks Asli: Barang sesuai pesanan ‚ò∫Ô∏è
# Setelah Pembersihan: barang sesuai pesanan
# Setelah Tokenisasi: ['barang', 'sesuai', 'pesanan']
# Setelah Stemming: ['barang', 'sesuai', 'pesan']
# --------------------------------------------------

# %% [markdown]
# Pisahkan data berlabel dan tak berlabel

# %%
df_labeled = df_selected[df_selected['sentiment'].notna()]
df_unlabeled = df_selected[df_selected['sentiment'].isna()]

# %% [markdown]
# # **DATA TRANSFORMASI**
#
# ---

# %% [markdown]
# Vektorisasi menggunakan TF-IDF dengan unigram, bigram, dan trigram

# %%
all_cleaned_content = pd.concat([df_labeled['cleaned_content'], df_unlabeled['cleaned_content']])
vectorizer = TfidfVectorizer(ngram_range=(1, 3), max_df=0.75, min_df=3, stop_words=stopwords_tambahan, max_features=5000)
all_features = vectorizer.fit_transform(all_cleaned_content)

# %% [markdown]
# Pisahkan fitur untuk data berlabel dan tak berlabel

# %%
X_labeled = all_features[:len(df_labeled)]
X_unlabeled = all_features[len(df_labeled):]
y_labeled = df_labeled['sentiment']

# %% [markdown]
# 10 sampel komentar acak dari kolom 'content' untuk analisis TF-IDF

# %%
sample_content = df['content'].sample(10, random_state=1).tolist() # Ambil 10 sampel komentar acak dari kolom 'content' untuk analisis TF-IDF
# Terapkan vektorisasi TF-IDF pada sampel komentar yang telah diambil
vectorizer = TfidfVectorizer()
X_sample = vectorizer.fit_transform(sample_content)
# Ubah hasil TF-IDF menjadi DataFrame agar lebih mudah dibaca
feature_names = vectorizer.get_feature_names_out()
tfidf_sample_df = pd.DataFrame(X_sample.toarray(), columns=feature_names)
# Tampilkan nilai TF-IDF untuk sampel komentar yang diambil
tfidf_sample_df.head()
# Out:
#     2x        3x       ada       aja  alhamdulillah    amanah     ampuh  \
# 0  0.0  0.000000  0.000000  0.000000            0.0  0.000000  0.000000
# 1  0.0  0.000000  0.000000  0.000000            0.0  0.000000  0.159903
# 2  0.0  0.150801  0.150801  0.150801            0.0  0.000000  0.000000
# 3  0.0  0.000000  0.000000  0.000000            0.0  0.000000  0.153389
# 4  0.0  0.000000  0.000000  0.000000            0.0  0.220124  0.000000
#
#        anti   awalnya    banget  ...  uda     untuk   ya      yang        yg  \
# 0  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.0  0.000000  0.159452
# 1  0.000000  0.000000  0.000000  ...  0.0  0.188101  0.0  0.000000  0.279792
# 2  0.000000  0.000000  0.000000  ...  0.0  0.000000  0.0  0.512778  0.000000
# 3  0.000000  0.180439  0.153389  ...  0.0  0.000000  0.0  0.153389  0.000000
# 4  0.220124  0.000000  0.000000  ...  0.0  0.000000  0.0  0.000000  0.000000
#
#    you  üëç       üòå       üòç       üôè
# 0  0.0  0.0  0.000000  0.000000  0.000000
# 1  0.0  0.0  0.000000  0.000000  0.000000
# 2  0.0  0.0  0.000000  0.000000  0.000000
# 3  0.0  0.0  0.180439  0.541316  0.000000
# 4  0.0  0.0  0.000000  0.000000  0.220124
#
# [5 rows x 156 columns]

# %% [markdown]
# # **DATA MINING (Model : Naive Bayes)**
#
# ---

# %% [markdown]
# Membagi data berlabel menjadi data latih dan data validasi

# %%
X_train, X_val, y_train, y_val = train_test_split(X_labeled, y_labeled, test_size=0.2, random_state=42)

# %% [markdown]
# Latih model Naive Bayes pada data berlabel

# %%
model = MultinomialNB()
model.fit(X_labeled, y_labeled)
# Out:
# MultinomialNB()

# %% [markdown]
# Evaluasi model pada data berlabel

# %%
y_pred_val = model.predict(X_val)
print("=== Laporan Klasifikasi pada Data Validasi ===")
print(classification_report(y_val, y_pred_val))
print("Akurasi pada data validasi:", accuracy_score(y_val, y_pred_val))
# Out:
# === Laporan Klasifikasi pada Data Validasi ===
#               precision    recall  f1-score   support
#
#      negatif       1.00      0.77      0.87        31
#       netral       0.94      0.71      0.81        45
#      positif       0.76      0.97      0.85        65
#
#     accuracy                           0.84       141
#    macro avg       0.90      0.82      0.84       141
# weighted avg       0.87      0.84      0.84       141
#
# Akurasi pada data validasi: 0.8439716312056738

# %% [markdown]
# Memprediksi sentimen untuk data yang belum berlabel

# %%
predicted_sentiment = model.predict(X_unlabeled)
df_unlabeled.loc[:, 'sentiment'] = predicted_sentiment

# %% [markdown]
# Gabungkan hasil prediksi ke dalam dataset asli

# %%
df_selected.update(df_unlabeled[['sentiment', 'cleaned_content']])

# %% [markdown]
# Verifikasi kolom 'cleaned_content' dan 'sentiment'

# %%
print("Verifikasi 'cleaned_content' dan 'sentiment' di df_selected:")
print(df_selected[['content', 'cleaned_content', 'sentiment']].head())
# Out:
# Verifikasi 'cleaned_content' dan 'sentiment' di df_selected:
#                                              content  \
# 0  Pertama kali coba karena baca ulasan di Quora ...
# 1  Penasaran bgt dari dulu udah laser jg bekas lu...
# 2  Udah ku pke beberapa kali sih, semoga bermanfa...
# 3                             kecewa, kemasan penyok
# 4                       Barang sesuai pesanan ‚ò∫Ô∏è
#
#                                      cleaned_content sentiment
# 0  pertama kali coba karena baca ulasan di quora ...   positif
# 1  penasaran bgt dari dulu udah laser jg bekas lu...    netral
# 2  udah ku pke beberapa kali sih semoga bermanfaa...   positif
# 3                              kecewa kemasan penyok   negatif
# 4                            barang sesuai pesanan      netral

# %% [markdown]
# Simpan hasil prediksi ke file CSV

# %%
df_selected.to_csv('final_hasil_prediksi_sentimen_naivebayes.csv', index=False)
print("Hasil prediksi sentimen telah disimpan dalam file 'final_hasil_prediksi_sentimen_naivebayes.csv'.")
# Out:
# Hasil prediksi sentimen telah disimpan dalam file 'final_hasil_prediksi_sentimen_naivebayes.csv'.

# %% [markdown]
# Membuat kolom untuk perbandingan sentimen manual dan prediksi

# %%
df_comparison = df_selected[['content', 'sentiment']].copy()
df_comparison['sentiment_prediksi'] = model.predict(all_features)

# %% [markdown]
# Menampilkan data yang diberi label manual dan data prediksi Naive Bayes

# %%
df_comparison_labeled = df_comparison[df_selected['sentiment'].notna()]  # Data berlabel manual
df_comparison_prediksi = df_comparison[df_selected['sentiment'].isna()]  # Data hasil prediksi
print("=== Data yang Diberi Label Manual ===")
print(df_comparison_labeled.head(10))  # Menampilkan 10 baris pertama data manual

print("\n=== Data Prediksi Naive Bayes ===")
print(df_comparison_prediksi.head(10))  # Menampilkan 10 baris pertama data prediksi
# Out:
# === Data yang Diberi Label Manual ===
#                                              content sentiment  \
# 0  Pertama kali coba karena baca ulasan di Quora ...   positif
# 1  Penasaran bgt dari dulu udah laser jg bekas lu...    netral
# 2  Udah ku pke beberapa kali sih, semoga bermanfa...   positif
# 3                             kecewa, kemasan penyok   negatif
# 4                       Barang sesuai pesanan ‚ò∫Ô∏è    netral
# 5  Baru pertama kali coba mudah mudahan bisa puda...   positif
# 6  Baru mau nyoba, semoga manjur menghilangkan be...   positif
# 7  Cottonbud gak dikasih, pelit banget, gimana pa...   negatif
# 8  Alhamdulillah Paketku sudah sampai pesanannya ...   positif
# 9  Dikasih thr sama kakaknya, MasyaAllah berkah s...   positif
#
#   sentiment_prediksi
# 0            positif
# 1            positif
# 2            positif
# 3            negatif
# 4             netral
# 5             netral
# 6            positif
# 7            positif
# 8            positif
# 9            positif
#
# === Data Prediksi Naive Bayes ===
# Empty DataFrame
# Columns: [content, sentiment, sentiment_prediksi]
# Index: []

# %% [markdown]
# Simpan perbandingan ke dalam file CSV

# %%
df_comparison.to_csv('perbandingan_sentimen_asli_dan_prediksi.csv', index=False)
print("Perbandingan sentimen asli dan prediksi telah disimpan dalam file 'perbandingan_sentimen_asli_dan_prediksi.csv'.")
# Out:
# Perbandingan sentimen asli dan prediksi telah disimpan dalam file 'perbandingan_sentimen_asli_dan_prediksi.csv'.

# %% [markdown]
# # **Visualisasi hasil evaluasi**
#
# ---

# %% [markdown]
# Confusion Matrix

# %%
conf_matrix_all = confusion_matrix(df_comparison['sentiment'], df_comparison['sentiment_prediksi'])
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_all, annot=True, fmt="d", cmap="YlGnBu", xticklabels=model.classes_, yticklabels=model.classes_)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix pada Keseluruhan Data")
plt.show()

# %% [markdown]
# Precision, Recall, dan F1-Score untuk setiap Kelas

# %%
y_true = df_comparison['sentiment']
y_pred = df_comparison['sentiment_prediksi']
unique_labels = y_true.unique()

metrics = precision_recall_fscore_support(y_true, y_pred, labels=unique_labels)
metric_df = pd.DataFrame({
    'Kelas Sentimen': unique_labels,
    'Precision': metrics[0],
    'Recall': metrics[1],
    'F1-score': metrics[2]
})

# Plot Precision, Recall, dan F1-Score per Kelas Sentimen
plt.figure(figsize=(10, 6))
metric_df.set_index('Kelas Sentimen').plot(kind='bar')
plt.title("Precision, Recall, dan F1-Score per Kelas Sentimen")
plt.ylabel("Nilai")
plt.xlabel("Kelas Sentimen")
plt.legend(loc='upper right')
plt.show()

# %% [markdown]
# Distribusi Sentimen Bar Chart

# %%
sentiment_counts = df['sentiment'].value_counts()
# Plot Distribusi Sentimen Bar Chart
plt.figure(figsize=(8, 6))
sns.barplot(x=sentiment_counts.index, y=sentiment_counts.values)
plt.xlabel('Sentimen')
plt.ylabel('Jumlah')
plt.title('Distribusi Sentimen (Positif, Negatif & Netral)')
plt.show()

# %% [markdown]
# Distribusi Sentimen Pie Chart

# %%
plt.figure(figsize=(8, 6))
plt.pie(sentiment_counts.values, labels=sentiment_counts.index, autopct='%1.1f%%', startangle=140, colors=['#66c2a5', '#fc8d62', '#8da0cb'])
plt.axis('equal')
plt.title('Proporsi Sentimen (Positif, Negatif & Netral)')
plt.show()

# %% [markdown]
# Wordcloud untuk ulasan Positif, Negatif dan Netral

# %%
def generate_wordcloud(df, sentiment_label, title):
    # Verifikasi apakah ada data untuk sentimen yang diberikan
    if sentiment_label not in df['sentiment'].unique():
        print(f"Tidak ada data untuk sentimen: {sentiment_label}")
        return
    # Gabungkan teks untuk Word Cloud
    text = ' '.join(df[df['sentiment'] == sentiment_label]['cleaned_content'].fillna(''))
    wordcloud = WordCloud(width=800, height=400, background_color='white', stopwords=stopwords_tambahan).generate(text)
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.title(title)
    plt.show()

# Tampilkan Word Cloud untuk setiap sentimen
generate_wordcloud(df_selected, 'positif', 'Word Cloud untuk Sentimen Positif')
generate_wordcloud(df_selected, 'negatif', 'Word Cloud untuk Sentimen Negatif')
generate_wordcloud(df_selected, 'netral', 'Word Cloud untuk Sentimen Netral')
